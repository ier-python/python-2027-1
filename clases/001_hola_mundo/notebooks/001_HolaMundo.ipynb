# %% [markdown]
# # Recomendaciones para aprender a usar la libreta de Jupyter.
#
# 1. Nombra siempre tus libretas, el estandard sugerido es `001_NombreAlusivo.ipynb`
# 2. Aprende los shortcuts para copiar, editar, ejecutar tus celdas, trata de depender lo menos de los botones
# 3. Comienza a visualizar que las celdas nos sirven para agrupar operaciones
# 4. `Restart the kernel and run all cells` es una de las mejores practicas, decide cuando ejecutarla
# 5. Guarda tu libreta despu'es de correr todas las celdas en orden

# %% [markdown]
# #  Hola mundo
#
# $ E = mc^2 $

# %% [markdown]
# ![image.png](attachment:08316ffc-ded3-4b84-b826-15cc7496c1b0.png)

# %%
a = 1
b = 2
c = a + b
c
# Out:
# 3

# %%
a
# Out:
# 1
